# %%
import pandas as pd
import json
from datetime import datetime, date, timedelta
import glob
import re
import spacy
nlp = spacy.load('de_core_news_sm')

# %%
storage = r'../scraping/data/storage/'

# %%
def timestamp_to_date(timestamp):
    return date.fromtimestamp(timestamp)

def format_text(text):
    # remove Uni-Code
    t = text.encode('latin-1', 'ignore').decode('latin-1')
    
    # Hashtags entfernen
    t = re.sub(r'#\w+', '', t)
    
    # Links entfernen
    t = re.sub(r'http\S+', '', t)
    
    # remove Steuersymbole/andere Zeichen
    t = re.sub(r'[\n\t\ \"\':+?!]+', ' ', t)
    
    return t

def format_words(word):
    return re.sub('[\[\-.,:?&()!@#|$0-9 ]', '', word)

ignore_words = ["SEIN", "EINEN", "WERDEN", "AUCH", "DIES", "HABEN", "SICH", "KÖNNEN", "NICHT", "NOCH", "MEIN"]

def frame_to_dic(dataframe):
    dic = {}
    for i in dataframe['text'].to_numpy():
        for j in nlp.tokenizer(i):
            s = (j.lemma_).upper()
            if len(s) < 4:
                continue
            if s in ignore_words:
                continue
            if (s in dic):
                dic[s] += 1
            else:
                dic[s] = 1
    return dic

def get_dic_around(date, dic_frame, day_range):
    res = {}
    for i in dic_frame[(dic_frame['date'] >= (date - timedelta(days=day_range))) & (dic_frame['date'] <= (date + timedelta(days=day_range)))]['dic']:
        res = {**res, **i}
    return res

def get_top_k(dictionary, k):
    n = sum(sorted(dictionary.values(), reverse=True)[:k])
    sort_dic = sorted(dictionary, key=dictionary.get, reverse=True)
    return {i: dictionary[i]/n for i in list(sort_dic)[:k]}

# %% [markdown]
# ### Initilize empty dataframe

# %%
df = pd.DataFrame(columns=['date', 'user', 'shortcode', 'platform', 'text'])

# %% [markdown]
# ### Instagram Daten hinzufügen

# %%
files = glob.glob(storage + '*.json')

for j in files:
    # Öffnen einer JSON Datei 
    f = open(j, mode="r", encoding="utf-8") 

    # JSON als dictionary 
    data = json.load(f)

    for i in data:
        
        text = i['text'].upper()
        
        if ('CORONA' in text) or ('COVID' in text) or ('SARS-COV-2' in text) or ('SARS COV' in text):
            
            date = timestamp_to_date(i['date'])
            user = i['user']
            shortcode = i['shortcode']
            platform = i['platform']
            text = format_text(i['text'])
            df = df.append({'date': date, 'user': user,
                            'shortcode': shortcode, 'platform': platform, 
                            'text': text}, ignore_index=True)

    # Closing file 
    f.close() 
    print('Completed:', j)
print('Done!')
# Out:
# Completed: ../scraping/data/storage\2020_1.json
# Completed: ../scraping/data/storage\2020_10.json
# Completed: ../scraping/data/storage\2020_11.json
# Completed: ../scraping/data/storage\2020_12.json
# Completed: ../scraping/data/storage\2020_2.json
# Completed: ../scraping/data/storage\2020_3.json
# Completed: ../scraping/data/storage\2020_4.json
# Completed: ../scraping/data/storage\2020_5.json
# Completed: ../scraping/data/storage\2020_6.json
# Completed: ../scraping/data/storage\2020_7.json
# Completed: ../scraping/data/storage\2020_8.json
# Completed: ../scraping/data/storage\2020_9.json
# Completed: ../scraping/data/storage\2021_1.json
# Completed: ../scraping/data/storage\2021_2.json
# Completed: ../scraping/data/storage\2021_3.json
# Completed: ../scraping/data/storage\2021_4.json
# Done!

# %% [markdown]
# ### Build dictionary frame

# %%
df
# Out:
#              date        user            shortcode platform  \
# 0      2020-01-28   BR_Presse  1222203172309151746  twitter
# 1      2020-01-31  derspiegel  1223347087716364288  twitter
# 2      2020-01-31  derspiegel  1223319549614804992  twitter
# 3      2020-01-31  derspiegel  1223225154702102534  twitter
# 4      2020-01-31  derspiegel  1223222791278931968  twitter
# ...           ...         ...                  ...      ...
# 55688  2021-04-01        welt  1377551392387297280  twitter
# 55689  2021-04-01        welt  1377535482419089408  twitter
# 55690  2021-04-01        welt  1377528682865131522  twitter
# 55691  2021-04-01        welt  1377488458869051393  twitter
# 55692  2021-04-01        welt  1377487731459252224  twitter
#
#                                                     text
# 0      Sondersendung Gesundheit spezial in Bayern Wie...
# 1      127 Tests waren negativ und einer positiv Mita...
# 2      Auch in manchen deutschen Apotheken werden Sch...
# 3      Und für alle, die noch mehr wissen wollen, hie...
# 4      In Bayern sind mittlerweile fünf -Fälle bekann...
# ...                                                  ...
# 55688  Frankreich und Italien verschärfen ihre Corona...
# 55689  Corona Neue Variante in Brasilien aufgetaucht ...
# 55690  Alles nur geklaut So dreist entstand die Anti-...
# 55691  Corona Dramatische Prognose vom RKI droht sich...
# 55692  Corona Alles nur geklaut So dreist entstand di...
#
# [55693 rows x 5 columns]

# %%
dic_frame = pd.DataFrame(columns=['date', 'dic'])

for i in df['date'].unique():
    frame = df[df['date'] == i]
    dic_frame = dic_frame.append({'date': i, 'dic': frame_to_dic(frame)}, ignore_index=True)

dic_frame = dic_frame.sort_values(by=['date'])
dic_frame
# Out:
#            date                                                dic
# 16   2020-01-09  {'FALL': 1, 'RÄTSELHAFT': 1, 'CHINESISCH': 1, ...
# 14   2020-01-11  {'DUTZEND': 1, 'MENSCH': 3, 'EINER': 4, 'NEUAR...
# 11   2020-01-17  {'MEHR': 1, 'MENSCH': 1, 'LEIDEN': 1, 'CHINA':...
# 15   2020-01-18  {'CHINA': 1, 'WEIT': 2, 'FALL': 1, 'AUFTRETEN'...
# 13   2020-01-19  {'AUSMASS': 1, 'MYSTERIÖS': 1, 'LUNGENKRANKHEI...
# ..          ...                                                ...
# 446  2021-04-04  {'CHORPROBE': 1, 'PFLEGEHEIM': 1, 'FITNESSSTUD...
# 445  2021-04-05  {'ARMIN': 3, 'WOLLEN': 7, 'NACHDENKEN': 2, '-M...
# 444  2021-04-06  {'NACH': 12, 'EINER': 11, 'WEIT': 6, 'CORONAFA...
# 443  2021-04-07  {'ZWEITE': 2, 'JAHR': 6, 'PANDEMIE': 4, 'ENDE'...
# 442  2021-04-08  {'EINE': 4, 'QUERDENKER«-KUNDGEBUNG': 1, 'BRIN...
#
# [450 rows x 2 columns]

# %%
d = get_dic_around(date=datetime(2020,12,12).date(), dic_frame=dic_frame, day_range=3)
d
# Out:
# {'KANZLERIN': 1,
#  'DRINGEN': 1,
#  'CORONAKRISE': 1,
#  'SCHNELLEN': 1,
#  'ENTSCHEIDUNG': 2,
#  'MINISTERPRÄSIDENTEN': 2,
#  'SCHLESWIG-HOLSTEIN': 2,
#  'SPRINGEN': 1,
#  'NACH': 13,
#  'EINER': 12,
#  'HARTEN': 2,
#  'LOCKDOWN': 9,
#  'IMMER': 2,
#  'LAUT': 1,
#  'QUERDENKER': 1,
#  'BADEN-WÜRTTEMBERG': 3,
#  'VERFASSUNGSSCHUTZ': 3,
#  'BEOBACHTEN': 1,
#  'WELCH': 2,
#  'FOLGE': 4,
#  'CORONA-PROTESTBEWEGUNG': 3,
#  'DEUTSCHLAND': 12,
#  'ANTWORT': 2,
#  'WICHTIG': 3,
#  'FRAGE': 1,
#  'WIESO': 1,
#  'EMOTIONAL': 2,
#  'CORONA-REDE': 1,
#  'RISKIEREN': 2,
#  'ABLEHNUNG': 1,
#  'WIDERWILLEN': 1,
#  'TROTZ': 1,
#  'ERZEUGEN': 1,
#  'WESHALB': 1,
#  'WELTWIRTSCHAFT': 1,
#  'HOFFEN': 1,
#  'WARUM': 4,
#  'NIEMAND': 1,
#  'RASSISMUS': 1,
#  'FUSSBALL': 2,
#  'WEGSEHEN': 1,
#  'DÜRFEN': 4,
#  'LAGE': 5,
#  'MITTWOCHABEND': 1,
#  '@OTRENKAMP': 1,
#  'GEBEN': 6,
#  'GROSS': 3,
#  'REGIONALE': 1,
#  'UNTERSCHIED': 1,
#  'CORONA-FALLZAHLEN': 1,
#  'KOMMEN': 4,
#  'ZUSTANDE': 1,
#  'EXPERTE': 2,
#  'THORSTEN': 1,
#  'LEHR': 1,
#  'ÜBER': 11,
#  'INFEKTIONSKETTEN': 1,
#  'FALSCH': 1,
#  'SICHERHEIT': 1,
#  'VERSCHIEDEN': 1,
#  'GEMÜT': 1,
#  'GELIEBT': 1,
#  'MENSCH': 9,
#  'COVID-19': 1,
#  'VERLIEREN': 2,
#  'SCHRECKLICH': 1,
#  'ABER': 8,
#  'GEHEN': 6,
#  'DAMIT': 3,
#  'WENN': 1,
#  'SELBST': 4,
#  'ANSTECKEN': 1,
#  'CORONA': 14,
#  'SCHULD': 1,
#  'VERANTWORTUNGSVOLL': 1,
#  'WOLLEN': 14,
#  'KATASTROPHENSCHUTZ': 1,
#  'POLITIK': 1,
#  'KALTE': 1,
#  'KRIEG': 1,
#  'MEHR': 16,
#  'INTERESSIEREN': 1,
#  'ERFAHRUNG': 1,
#  'CORONA-PANDEMIE': 4,
#  'SOLL': 2,
#  'REFORM': 1,
#  'METROPOLE': 2,
#  'GEISTERSTÄDTEN': 2,
#  'DISTANZ': 2,
#  'SPIEGEL': 1,
#  'REISEN': 1,
#  'FILMISCH': 2,
#  'DURCH': 2,
#  'JAHR': 6,
#  'WELT': 1,
#  'AUSNAHMEZUSTAND': 2,
#  'KRITISIEREN': 1,
#  'BUNDESLÄNDER': 1,
#  'MAHNEN': 2,
#  'DERJENIGE': 1,
#  'WISSENSCHAFT': 1,
#  'ZUHÖREN': 1,
#  'FORDERN': 4,
#  'HART': 1,
#  'CORONA-MASSNAHMEN': 2,
#  'BUNDESTAG': 1,
#  'SEHR': 1,
#  'EMOTIONALE': 1,
#  'REDE': 2,
#  'HALTEN': 1,
#  'VIDEO': 1,
#  '@A_EVELT': 1,
#  'HAMBURG': 1,
#  'BILDUNGSSENATOR': 1,
#  'TIES': 1,
#  'RABE': 1,
#  'SPRECHEN': 3,
#  'SPIEGEL«-KINDERREPORTERINNEN': 1,
#  'FEHLEND': 1,
#  'LEHRKRÄFTE': 1,
#  'COMPUTER': 1,
#  'SCHULE': 3,
#  'BARCELONA': 1,
#  'VIER': 1,
#  'LÖWE': 2,
#  'COVID-19-INFEKTION': 1,
#  'BESSERUNG': 1,
#  'INFIZIERT': 1,
#  'SYMPTOMFREIER': 1,
#  'PFLEGER': 1,
#  'TIER': 2,
#  'INFEKTIONSZAHLEN': 2,
#  'STEIGEN': 1,
#  'INTENSIVSTATION': 1,
#  'KAUM': 1,
#  'FREIE': 1,
#  'BETT': 1,
#  'KONSEQUENZ': 1,
#  'VERSCHÄRFEN': 2,
#  'KALIFORNIEN': 1,
#  'MACHEN': 4,
#  'DICHT': 1,
#  'WIDERSTAND': 1,
#  'OFFIZIELL': 1,
#  'SEITE': 1,
#  'FANGESÄNGE': 1,
#  'JUBEL': 1,
#  'PFIFFE': 1,
#  'VERBREITEN': 1,
#  'CORONAVIRUS': 3,
#  'FUSSBALLSTADION': 1,
#  'DAGEGEN': 1,
#  'FORSCHER': 1,
#  'JETZT': 4,
#  'HERAUSFINDEN': 1,
#  'SPEKTAKULÄR': 1,
#  'EXPERIMENT': 1,
#  'KREUZFAHRTSCHIFF': 2,
#  'QUANTUM': 1,
#  'SEAS': 1,
#  'HÄNGEN': 1,
#  'SINGAPUR': 2,
#  'FEST': 1,
#  'GRUND': 3,
#  'CORONA-FALL': 1,
#  'BORD': 1,
#  'QUERDENKEN': 1,
#  'STUTTGART': 2,
#  'KEIMZELLE': 2,
#  'SPIEGEL-INFORMATIONEN': 1,
#  'GRUPPE': 2,
#  'FALL': 1,
#  'BADEN-WÜRTTEMBERGISCHEN': 2,
#  'DEUTSCH': 3,
#  'GESUNDHEITSÄMTER': 1,
#  'MELDEN': 6,
#  'ROBERT': 1,
#  'KOCH-INSTITUT': 1,
#  'NEUE': 7,
#  'TODESFÄLLE': 4,
#  'ZUSAMMENHANG': 1,
#  'INNERHALB': 2,
#  'BEIM': 2,
#  'BISHERIG': 1,
#  'REKORDSTAND': 1,
#  'WÄHREND': 2,
#  'ZAHL': 2,
#  'NEUINFEKTIONEN': 1,
#  'STAGNIEREN': 1,
#  'CORONA-INFEKTION': 2,
#  'NRW-REGIERUNGSCHEF': 1,
#  'LASCHET': 1,
#  'PLÄDIEREN': 1,
#  'ECHT': 2,
#  'JAHRESWECHSEL-LOCKDOWN': 1,
#  'ÜBERBLICK': 2,
#  'FRÜHJAHR': 1,
#  'FEIERN': 1,
#  'HELD': 1,
#  'ANETT': 1,
#  'HOERENZ': 1,
#  'INTENSIVPFLEGEKRAFT': 1,
#  'CHARITÉ': 1,
#  'BILANZIEREN': 1,
#  '-JAHR': 1,
#  'VOLLE': 1,
#  'STADIUM': 1,
#  'DÄMMERSCHOPPEN': 1,
#  'DACHTERRASSEN': 1,
#  'PARTY': 1,
#  'VIEL': 12,
#  'STAAT': 1,
#  'ASIEN': 3,
#  'AUSTRALIEN': 1,
#  'NEUSEELAND': 1,
#  'STEHEN': 5,
#  '-KRISE': 1,
#  'EUROPA': 5,
#  'GENAU': 2,
#  'BLICK': 1,
#  'LOHNEN': 1,
#  '@FAEHNDERS': 1,
#  'SCHREIBEN': 2,
#  'F.A.Z.': 1,
#  'PODCAST': 1,
#  'SERIE': 1,
#  '2020': 1,
#  'ZURÜCKBLICKEN': 1,
#  'AUFTAKT': 2,
#  '@KLUEBERBLICK': 1,
#  'FEUILLETON-HERAUSGEBER': 1,
#  'JÜRGEN': 1,
#  'KAUBE': 1,
#  'KULTURJAHR': 1,
#  'KULTUR': 1,
#  'VERÄNDERN': 1,
#  '-PANDEMIE': 5,
#  'ETWAS': 1,
#  'GUTES': 1,
#  'HABE': 1,
#  'DANN': 5,
#  'DASS': 7,
#  'ZEIGEN': 4,
#  'WOZU': 1,
#  'HERZ': 1,
#  'HAND': 1,
#  'NEHMEN': 4,
#  'SAGEN': 11,
#  'APPELLIEREN': 1,
#  'WEIT': 4,
#  'VERSCHÄRFUNG': 1,
#  '@ECKARTLOHSE': 1,
#  'VIERTEL': 1,
#  '-FÄLLE': 3,
#  '-OPFER': 1,
#  'BUCHE': 1,
#  'WOCHE': 3,
#  'OFFENBACH': 1,
#  'RATHAUSCHEF': 1,
#  'LEHNEN': 1,
#  'DERWEIL': 1,
#  'NEUERLICH': 1,
#  'LOCKERUNGEN': 2,
#  'WEIHNACHTEN': 12,
#  'SCHON': 4,
#  'BERICHTEN': 5,
#  '@JOCHEN102': 2,
#  '@THORSTEN_WINTER': 1,
#  'GROSSHERZOGTUM': 1,
#  '-HOTSPOT': 1,
#  'HOCH': 3,
#  'DOCH': 5,
#  'SCHÜLER': 1,
#  'SOLLEN': 5,
#  'DARUNTER': 1,
#  'LEIDEN': 1,
#  'TEST': 3,
#  'KLASSE': 1,
#  'ISOLIEREN': 1,
#  'PRÄSENZUNTERRICHT': 1,
#  'MODELL': 1,
#  'VERANTWORTUNGSLOS': 1,
#  'HAUFEN': 1,
#  '-PATIENT': 1,
#  'HELMUT': 1,
#  'OESTREICH': 1,
#  'SAMSTAG': 1,
#  'DEMONSTRIEREN': 1,
#  'FASSUNGSLOS': 1,
#  '@KEHLERMALI': 1,
#  'BLOCKIEREN': 1,
#  'MILLIARDENSCHWERE': 2,
#  '-KONJUNKTURHILFEN': 1,
#  'MITTWOCH': 2,
#  'ENDEN': 1,
#  'GESETZT': 1,
#  'FRIST': 1,
#  'BEID': 1,
#  'LAND': 8,
#  'SELBSTÄNDIG': 1,
#  'KÜNFTIG': 2,
#  'FÜRS': 1,
#  'VORSORGEN': 1,
#  'MÜSSEN': 4,
#  'VERLANGEN': 1,
#  'ARBEITSMINISTER': 1,
#  'DABEI': 1,
#  'GERADE': 2,
#  'BESONDERS': 3,
#  'BELASTEN': 2,
#  'KRITIK': 1,
#  'VORHABEN': 1,
#  'WEGEN': 7,
#  'ZEITPUNKTS': 1,
#  '@KERSTINSCHWENN': 1,
#  'ENTWICKLUNG': 2,
#  'FLIEGEND': 1,
#  'TAXI': 1,
#  'ZWEIT': 2,
#  'ZUKUNFTSPROJEKT': 1,
#  'WENIG': 1,
#  'ÜBERAUS': 1,
#  'AGGRESSIV': 1,
#  'AUFTRETEND': 1,
#  'UNTERNEHMEN': 4,
#  'SCHAFFEN': 1,
#  'TÜRKISCH': 1,
#  'REGIERUNG': 4,
#  'AUSMASS': 1,
#  'LANG': 2,
#  'BESCHÖNIGEN': 1,
#  'ASYMPTOMATISCHE': 1,
#  'MITZÄHLEN': 1,
#  'WHO-ZÄHLWEISE': 1,
#  'ZURÜCKKEHREN': 1,
#  'ERLEBEN': 1,
#  'REALITÄTSSCHOCK': 1,
#  'MUSS': 1,
#  'VORZEITIG': 1,
#  'WEIL': 1,
#  'PASSAGIER': 1,
#  'POSITIV': 4,
#  'TESTEN': 1,
#  'BUNDESKANZLERIN': 1,
#  'KAMPF': 1,
#  'GEGEN': 9,
#  'WEITREICHEND': 1,
#  'SCHLIESSUNG': 1,
#  'JANUAR': 2,
#  'GESCHÄFT': 1,
#  'SCHLIESSEN': 2,
#  'FERIEN': 4,
#  'VERLÄNGERN': 1,
#  'LIVEBLOG': 2,
#  'BINNEN': 1,
#  'STUNDE': 2,
#  'GEMELDET': 1,
#  'SPRUNGHAFT': 1,
#  'ANSTEIGEN': 1,
#  'HÖCHSTSTAND': 1,
#  'ERREICHEN': 2,
#  'HÄRTERE': 1,
#  'CORONA-BESCHRÄNKUNGEN': 1,
#  'WAHRSCHEINLICHER': 1,
#  'STREIT': 1,
#  'ERHÖHUNG': 1,
#  'RUNDFUNKBEITRAGS': 1,
#  'ESKALIEREN': 1,
#  'BORIS': 1,
#  'JOHNSON': 1,
#  'TREFFEN': 3,
#  'URSULA': 1,
#  'LEYEN': 1,
#  'SONST': 1,
#  '@SEREUTER': 1,
#  'SPEKTAKEL': 1,
#  'FÄLLEN': 1,
#  'WELTCUP-SKISPRINGEN': 1,
#  'WILLINGEN': 1,
#  'ENDE': 1,
#  'LEER': 1,
#  'RANG': 1,
#  'AUSTRAGEN': 2,
#  '-AUSGANGSSPERRE': 1,
#  'NACHTS': 1,
#  'FAST': 1,
#  'KEIN': 7,
#  'RAUS': 1,
#  'VERBOT': 2,
#  'GEPLANT': 2,
#  '-DEMO': 1,
#  'ORGANISATOR': 1,
#  'ERWÄGEN': 1,
#  'RECHTLICHE': 1,
#  'SCHRITT': 1,
#  '-GELDER': 1,
#  'VERZÖGERT': 1,
#  'NOVEMBERHILFE': 1,
#  'FRUSTRIERT': 1,
#  'HOTELIERS': 1,
#  'GASTWIRTE': 1,
#  'HESSEN': 1,
#  'TEIL-LOCKDOWN': 1,
#  'GAST': 1,
#  'COMMUNITY': 1,
#  'QUEEREN': 1,
#  'BRAUCHEN': 1,
#  'TICKER': 3,
#  'PFLEGEKRÄFTE': 1,
#  'ARBEITSBEDINGUNGEN': 1,
#  '1.658': 1,
#  'AUSGANGSSPERRE-AUSNAHMEN': 1,
#  'SPANISCH': 1,
#  'WIEDER': 3,
#  'GESUND': 2,
#  'VERMUTLICH': 1,
#  'ZOO-PFLEGERN': 1,
#  'CYBERATTACKE': 2,
#  'EUROPÄISCH': 1,
#  'ARZNEIMITTELAGENTUR': 1,
#  'ANGABE': 2,
#  'PFIZER': 4,
#  'UNRECHTMÄSSIG': 1,
#  'DOKUMENT': 2,
#  'ZULASSUNGSANTRAG': 1,
#  'CORONA-IMPFSTOFF': 8,
#  'ZUGREIFEN': 2,
#  'TSCHECHIEN': 1,
#  'PARLAMENT': 1,
#  'CORONA-NOTSTAND': 1,
#  'KURZ': 4,
#  'JUNG': 1,
#  'FALLZAHLEN': 1,
#  'ERFURT': 1,
#  'BAUSEWEIN': 1,
#  'DRÄNGEN': 1,
#  'STRENG': 1,
#  'CORONA-REGELN': 1,
#  'THÜRINGEN': 1,
#  'BEISPIEL': 1,
#  'SACHSEN': 2,
#  'BAYERN': 1,
#  'FOLGEN': 1,
#  'VERDRÄNGUNGSEFFEKTE': 1,
#  'VERMEIDEN': 1,
#  'DORT': 2,
#  'EINKAUFEN': 1,
#  'KANADA': 4,
#  'BIONTECH': 3,
#  'NOTFALLZULASSUNG': 3,
#  'ERTEILEN': 1,
#  'GROSSBRITANNIEN': 1,
#  'BEREITS': 4,
#  'SEIT': 2,
#  'GESTERN': 2,
#  'EINSATZ': 1,
#  'GOLFSTAAT': 1,
#  'BAHRAIN': 1,
#  'ZULASSEN': 8,
#  'REIHENFOLGE': 1,
#  'CORONA-IMPFUNGEN': 1,
#  'GESETZ': 1,
#  'REGELN': 1,
#  'FDP-GESUNDHEITSPOLITIKERIN': 1,
#  'CHRISTINE': 1,
#  'ASCHENBERG-DUGNUS': 1,
#  '@CAD59': 1,
#  'BEFÜRCHTEN': 1,
#  'HINTERGRUND': 1,
#  'ÜBERGRIFF': 1,
#  'RADIKAL': 1,
#  'ANHÄNGER': 1,
#  '-BEWEGUNG': 1,
#  'ATTACKE': 1,
#  'PERSON': 1,
#  'INSTITUTION': 1,
#  'MÖGLICH': 2,
#  'DATUM': 1,
#  'HUNDERTTAUSENDEN': 1,
#  'CORONA-INFIZIERTEN': 1,
#  'MOSKAU': 1,
#  'ÖFFENTLICHKEIT': 1,
#  'LANGEN': 1,
#  'BEHÖRDENANGABEN': 1,
#  'MITARBEITER': 2,
#  'DATEI': 1,
#  'DRITTE': 1,
#  'WEITERGEBEN': 1,
#  'GOOGLE-SUCHTRENDS': 1,
#  'GESELLSCHAFT': 3,
#  'BESCHÄFTIGEN': 1,
#  'DIESES': 1,
#  'GEDENKEN': 1,
#  'ALLE': 2,
#  'PAAR': 1,
#  'ÜBERRASCHUNG': 1,
#  'BRITISCH': 2,
#  'ARZNEIMITTELAUFSICHT': 1,
#  'EMPFEHLEN': 1,
#  'BIONTECH-PFIZER': 1,
#  'SCHWER': 3,
#  'ALLERGIE': 2,
#  'EINSETZEN': 1,
#  'ZWEI': 3,
#  'IMPFUNG': 2,
#  'ALLERGISCHE': 3,
#  'REAKTION': 1,
#  'APPELL': 2,
#  'BEVÖLKERUNG': 1,
#  'DRESDNER': 2,
#  'KLINIK': 1,
#  'WARNEN': 1,
#  'KOLLAPS': 1,
#  'GESUNDHEITSSYSTEMS': 1,
#  'NEUER': 1,
#  'WÖCHENTLICH': 1,
#  'POLITIKER-RUFE': 1,
#  'SCHARF': 2,
#  'AKTUELLE': 2,
#  'MELDUNG': 1,
#  'RUND': 2,
#  'ÜBER-60-JÄHRIGE': 1,
#  'CORONA-RISIKOGRUPPEN': 1,
#  'BEKOMMEN': 1,
#  'DREI': 1,
#  'FFP2-MASKEN': 1,
#  'APOTHEKE': 3,
#  'BUNDESGESUNDHEITSMINISTER': 6,
#  'SPAHN': 9,
#  'ANKÜNDIGEN': 1,
#  'DAFÜR': 5,
#  'PERSONALAUSWEIS': 1,
#  'VORLEGEN': 3,
#  'DAUERN': 1,
#  'CORONA-ZAHLEN': 1,
#  'SENKEN': 1,
#  'UNIVERSITÄT': 1,
#  'SAARLAND': 1,
#  'MEHRER': 1,
#  'DICK': 1,
#  'STUDIE': 2,
#  'ROBERT-KOCH-INSTITUTS': 1,
#  'WIEGEN': 1,
#  'DEUTSCHE': 4,
#  'APRIL': 1,
#  'AUGUST': 1,
#  'SCHNITT': 1,
#  'KILO': 1,
#  'GLEICH': 1,
#  'ZEIT': 3,
#  'DAVOR': 1,
#  'BEWEGUNG': 1,
#  'CORONA-KRISE': 1,
#  'KREDIT': 1,
#  'SCHULDE': 1,
#  'BLEIBEN': 1,
#  'NÄCHST': 1,
#  'GENERATION': 1,
#  'DAZU': 1,
#  'BURGENLANDKREIS': 1,
#  'SCHRÄNKEN': 1,
#  'PFLEGEHEIM-BESUCHE': 1,
#  'LANDKREIS': 2,
#  'TEILEN': 1,
#  'CORONA-INFEKTIONSZAHLEN': 1,
#  'BEWOHNER': 1,
#  'BESUCHER': 1,
#  'EMPFANGEN': 1,
#  'DIESER': 1,
#  'NEGATIV': 1,
#  'ANTIGEN-SCHNELLTEST': 1,
#  'VORWEISEN': 1,
#  'GENERALDEBATTE': 1,
#  'MERKEL': 4,
#  'VERTEIDIGEN': 4,
#  'UMGANG': 1,
#  'DARAUF': 1,
#  'ZÄHLEN': 1,
#  'KRISE': 1,
#  'ERFOLGREICH': 1,
#  'BEWÄLTIGEN': 1,
#  'NEUVERSCHULDUNG': 1,
#  'AKTUELL': 1,
#  'AUSNAHMESITUATION': 2,
#  'RECHTFERTIGEN': 1,
#  'BUNDESHAUSHALT': 1,
#  'AFD-FRAKTIONSCHEFIN': 1,
#  'WEIDEL': 1,
#  'CORONA-POLITIK': 1,
#  'DREIVIERTELJAHR': 1,
#  'STOCHERN': 1,
#  'NEBEL': 1,
#  'KLAMMERN': 1,
#  'UNTAUGLICH': 1,
#  'HOLZHAMMERMETHODE': 1,
#  'MEISTGESUCHT': 1,
#  'STICHWORT': 1,
#  'GANZ': 1,
#  'VORNE': 1,
#  'GOOGLE-JAHRESRÜCKBLICK': 1,
#  'US-WAHL': 1,
#  'WETTER': 1,
#  'MORGEN': 6,
#  'HÄUFIG': 1,
#  'U.A.': 1,
#  'MUNDSCHUTZ': 1,
#  'WANN': 2,
#  'ÖFFNEN': 1,
#  'FRISEUR': 2,
#  'ONLINE': 1,
#  'CHATGRUPPEN': 1,
#  'DEMONSTRATION': 2,
#  'UNTERSCHIEDLICH': 1,
#  '-GRUPPE': 1,
#  'CORONA-EINSCHRÄNKUNGEN': 1,
#  'INZWISCHEN': 1,
#  'BEOBACHTUNG': 1,
#  'GRUPPIERUNG': 1,
#  'STAATLICHE': 1,
#  'HILFSGELDER': 1,
#  'ANWEISEN': 1,
#  'LÄSST': 2,
#  'WARTEN': 1,
#  'BUNDESREGIERUNG': 2,
#  'KÄMPFEN': 1,
#  'TECHNIK': 1,
#  'SOFTWARE': 1,
#  'REPORTER': 1,
#  'RALF': 1,
#  'GEISSLER': 1,
#  'UMHÖREN': 1,
#  'REKORD': 1,
#  'CORONA-TODESFÄLLEN': 1,
#  'STERBEN': 1,
#  'COVID-19-PATIENTEN': 1,
#  '20.815': 1,
#  'ANGEBEN': 1,
#  'GROSSTEIL': 1,
#  'VERBANDSVORSITZENDER': 1,
#  'GLASER': 1,
#  'AUSWEITEN': 1,
#  'THEMA': 2,
#  'FINDEN': 6,
#  'MAGDEBURGER': 1,
#  'LICHTERWELT': 1,
#  'LOCKEN': 1,
#  'EINIG': 1,
#  'SORGEN': 3,
#  'GREIFEN': 1,
#  'DONNERSTAG': 2,
#  '-SCHUTZMASSNAHMEN': 1,
#  'GELTEN': 4,
#  'LANDKREISEN': 1,
#  'GESAMT': 1,
#  'ÖFFENTLICH': 1,
#  'RAUM': 1,
#  'LANDKREISE': 2,
#  'GROSSSTADT': 1,
#  'HEUTE': 9,
#  '2.500': 1,
#  '-NEUINFEKTIONEN': 1,
#  '-INFEKTION': 2,
#  'SAISONGESCHÄFT': 1,
#  'PFLEGEHEIME': 1,
#  'EKLATANTER': 1,
#  'VERSTOSS': 1,
#  'GELTEND': 2,
#  '-REGELN': 2,
#  'ANZEIGEN': 1,
#  'PASS': 1,
#  'ANDER': 4,
#  'EINDRINGLICH': 2,
#  'RICHTEN': 1,
#  'GEMEINSAM': 1,
#  'REGION': 2,
#  'ZUSPITZEND': 1,
#  'VERSORGUNG': 1,
#  '-19-PATIENTEN': 1,
#  'HINWEISEN': 1,
#  '@AWOTHUERINGEN': 1,
#  'VORSITZENDE': 1,
#  'NACHDEM': 1,
#  'AMTSINHABER': 1,
#  'ZURÜCKTRETEN': 1,
#  'WAHL': 1,
#  'NACHFOLGER': 1,
#  'VERZÖGERN': 1,
#  'RECHTSSTREIT': 1,
#  'ENTLASSUNG': 1,
#  'EX-AJS-MANAGER': 1,
#  'HACK': 1,
#  'HAMBURGER': 1,
#  'STABILISIERUNGS-FONDS': 1,
#  'MITTELSTÄNDISCH': 1,
#  'START': 1,
#  'FIRMA': 1,
#  'HELFEN': 1,
#  'WIRTSCHAFTLICH': 1,
#  'SCHWIERIGKEIT': 1,
#  'GERATEN': 1,
#  'GEWERKSCHAFT': 1,
#  'VER.DI': 1,
#  'HOCHBAHN': 1,
#  'TARIFABSCHLUSS': 1,
#  'EINIGEN': 1,
#  'WARNSTREIK': 1,
#  'U-BAHNEN': 1,
#  'UMSTRITTEN': 1,
#  'SOZIALBEHÖRDE': 1,
#  'VERGLEICH': 1,
#  'VORTAG': 1,
#  'CORONA-NEUINFEKTIONEN': 2,
#  'REGISTRIEREN': 2,
#  'FÜNF': 5,
#  'DIENSTAG': 3,
#  'BEGRIFF': 1,
#  'DEUTSCHLANDWEIT': 1,
#  'GEGOOGELT': 1,
#  'MEIST': 3,
#  'ZUSAMMEN': 1,
#  'WORT': 1,
#  'MASKENPFLICHT': 1,
#  'HERVOR': 3,
#  'TREND': 1,
#  'GOOGLE': 1,
#  'HAUPTSITZ': 1,
#  'KUPFERPRODUZENT': 1,
#  'AURUBIS': 1,
#  'TROTZEN': 2,
#  'PANDEMIE': 6,
#  'GLÄNZEND': 1,
#  'DENNOCH': 1,
#  'KONZERN': 1,
#  'STELLE': 1,
#  'STREICHEN': 1,
#  'MECKLENBURG-VORPOMMERN': 1,
#  'HÖCHSTWERT': 2,
#  'LABORBESTÄTIGTEN': 1,
#  'VERZEICHNEN': 2,
#  'MINISTERPRÄSIDENTIN': 1,
#  'SCHWESIG': 1,
#  'KÜNDIGEN': 1,
#  'MASSNAHME': 1,
#  '@JOREK7': 1,
#  '@C_DROSTEN': 1,
#  'HALLO': 1,
#  'THESE': 2,
#  'SYMPTOMLOSE': 1,
#  'BEZIEHEN': 1,
#  'DROSTEN': 1,
#  'HIER': 4,
#  'CORONAINFIZIERTEN': 1,
#  'SYMPTOMLOS': 1,
#  'BESCHREIBEN': 1,
#  'CORONA-TICKER': 2,
#  'BEGINN': 1,
#  'BUNDESWEHR': 1,
#  'KASERNE': 1,
#  'ZWISCHENLAGER': 1,
#  'BEREITSTELLEN': 1,
#  'WISSEN': 1,
#  'BISHER': 1,
#  'CORONA-IMPFUNG': 1,
#  'STADT': 2,
#  'SCHEINEN': 1,
#  'PFLEGEHEIMBEWOHNER': 1,
#  'SCHÜTZEN': 2,
#  'LAUFEN': 1,
#  'TÜBINGEN': 1,
#  'ANDERS': 5,
#  'SINKEN': 2,
#  '-INFEKTIONEN': 2,
#  'ERWARTEN': 2,
#  'PAUSCHAL': 2,
#  'BESUCHSVERBOT': 1,
#  'PFLEGEHEIMEN': 2,
#  'LANDESGESUNDHEITSMINISTER': 1,
#  '@MANNELUCHA': 1,
#  '4.042': 1,
#  'LIEGEN': 1,
#  '3.160.': 1,
#  'LANDESWEITE': 1,
#  'SIEBEN-TAGE-INZIDENZ': 1,
#  '160,2': 1,
#  'INFEKTION': 1,
#  '100.000': 2,
#  'EINWOHNER': 2,
#  'MESSE': 2,
#  'GROSSVERSUCH': 1,
#  'FREIWILLIG': 1,
#  'HELFER': 1,
#  'ZIEL': 3,
#  'ABLAUF': 1,
#  '-MASSENIMPFUNG': 1,
#  'PROBEN': 1,
#  '@STR_AIRPORT': 1,
#  'BRECHEN': 1,
#  'PASSAGIERZAHLEN': 1,
#  'AUSSICHT': 2,
#  'VERHALTEN': 2,
#  '-VERORDNUNG': 1,
#  'CORONA-': 2,
#  'ANGEBOTEN': 1,
#  'SCHULLEITUNGEN': 1,
#  'UMFRAGE': 1,
#  'OFFEN': 1,
#  '@KORDAKERSTIN': 1,
#  'MÖGEN': 1,
#  'STAND': 1,
#  'BEZUG': 1,
#  'VERÄNDERUNG': 1,
#  'BESTIMMUNG': 1,
#  'ETC.': 1,
#  'INFORMIEREN': 2,
#  'DIREKT': 1,
#  'DARÜBER': 1,
#  'NATÜRLICH': 1,
#  'BEHANDELN': 1,
#  'CORONA-LOCKDOWNS': 1,
#  'BESUCHSVERBOTE': 1,
#  'LIVE-BLOG': 1,
#  '-NEWS': 2,
#  'CYBERANGRIFF': 2,
#  'ARZNEIMITTELBEHÖRDE': 2,
#  'ZUFOLGE': 1,
#  'IMPFSTOFF': 5,
#  'VAKZIN': 1,
#  'GENEHMIGUNG': 2,
#  'AUSGANGSSPERREN': 3,
#  'WECHSELUNTERRICHT': 1,
#  'ALKOHOLVERBOT': 1,
#  'BÜRGER': 1,
#  'EINSCHRÄNKUNG': 1,
#  'EINSTELLEN': 1,
#  'FLUGSCHAM': 1,
#  'ERZWINGEN': 1,
#  'WELTWEIT': 1,
#  'AIRLINE': 1,
#  'BODEN': 1,
#  'LUFTHANSA': 3,
#  'EPIDEMIOLOGINNEN': 1,
#  'EPIDEMIOLOGEN': 1,
#  'EINBLICK': 1,
#  'PERSÖNLICH': 1,
#  'ERKLÄREN': 1,
#  'HÄNDESCHÜTTELN': 1,
#  'FRÜH': 1,
#  'IDEE': 1,
#  'VORLÄUFIG': 1,
#  'MITTE': 3,
#  'ONLINE-PORTAL': 1,
#  'AIRBNB': 2,
#  'TECH-BÖRSE': 1,
#  'NASDAQ': 1,
#  'PREMIERE': 1,
#  'PUNKT': 1,
#  'HÖCHSTSTÄNDE': 2,
#  'UNGEDULDIG': 1,
#  'AUFTRITT': 3,
#  'ANGELA': 2,
#  'SEHEN': 1,
#  'STARK': 1,
#  'SIBEL': 1,
#  'WEGSPERREN': 1,
#  'UNTERSTÜTZEN': 1,
#  '-FORDERUNGEN': 1,
#  'PAPETERIE': 1,
#  'LIEBHABER': 1,
#  'EINMAL': 2,
#  'EGAL': 1,
#  'KLEBEZETTEL': 1,
#  'ORDNER': 1,
#  'AUSSEHEN': 1,
#  'ODER': 1,
#  'MARKERN': 1,
#  'ZOOM-KONFERENZEN': 1,
#  'MÄNNCHEN': 1,
#  'MALEN': 1,
#  'LEBEN': 2,
#  'HÖCHSTAND': 2,
#  'CORONA-TOTEN': 1,
#  'NRW-MINISTERPRÄSIDENT': 1,
#  'BUNDESWEITE': 1,
#  'CORONA-WARN-APP': 1,
#  'VÖLLIG': 1,
#  'QUELLOFFENEN': 1,
#  'VARIANTE': 1,
#  'ALLERDINGS': 2,
#  'ANDROID-NUTZER': 1,
#  'PROGRAMMIERT': 1,
#  'ENTWICKLER': 1,
#  'DEZEMBER': 8,
#  'BAYER': 1,
#  'LAGERN': 2,
#  'KINDERGÄRTEN': 2,
#  'EINZELHANDEL': 1,
#  'MONTAG': 3,
#  'BRASILIEN': 1,
#  'SICHERN': 2,
#  'MILLION': 3,
#  'BIONTECH-IMPFDOSEN': 1,
#  'ZWEITHÖCHSTE': 1,
#  'TODESOPFERN': 1,
#  'VORSTOSS': 1,
#  'CORONA-HILFEN': 3,
#  'HACKER': 1,
#  'KORRUPTION': 1,
#  'INDONESIEN': 1,
#  'ERST': 8,
#  'HUMMER': 1,
#  'BIONTECH-IMPFSTOFF': 1,
#  'UKRAINE': 1,
#  'JAHRESEND-LOCKDOWN': 1,
#  'RÜCKEN': 1,
#  'NÄHERN': 1,
#  'LEIDENSCHAFT': 1,
#  'PHYSIKERIN': 1,
#  'BEHÖRDE': 1,
#  'ALLERGIKER': 2,
#  'MÜNCHNER': 1,
#  'SICHERHEITSKONFERENZ': 1,
#  'VERSCHIEBEN': 1,
#  'CORONA-ABSATZFLAUTE': 1,
#  'HERSTELLER': 1,
#  'GLÜHWEIN': 1,
#  'BUNKERN': 1,
#  'RUSSISCHES': 1,
#  'STAATSMEDIUM': 1,
#  'KRUDE': 1,
#  'CORONA-SKEPTIKER': 1,
#  'JUGENDLICHE': 1,
#  'FAKE': 1,
#  'NEWS': 2,
#  'KONFRONTIEREN': 1,
#  'ERNEUTER': 1,
#  'CORONA-TODESFÄLLE': 1,
#  'ETAT': 1,
#  'GELD': 1,
#  'STÄDTETAG': 1,
#  'STILLSTAND': 1,
#  'HUNGERKRISE': 1,
#  'TEIL-LOCKDOWNS': 1,
#  'NEUINFIZIERTEN': 1,
#  'DAHER': 1,
#  '.@ARMINLASCHET': 1,
#  '@LANDNRW': 1,
#  'JAHRESWECHSEL': 3,
#  'EMPFEHLUNG': 1,
#  '@LEOPOLDINA': 1,
#  'MORGENMAGAZIN': 1,
#  'ARZNEIMITTEL-BEHÖRDE': 1,
#  'HACKER-ANGRIFF': 1,
#  'VERÜBEN': 1,
#  'DERZEIT': 1,
#  'PRÜFEN': 1,
#  'ZULASSUNG': 10,
#  'CORONA-IMPFSTOFFES': 1,
#  'EINE': 5,
#  'FALLEN': 2,
#  'BRITISCHE': 1,
#  'RATEN': 2,
#  'VORERST': 1,
#  '@BIONTECH_GROUP': 2,
#  'MASSENIMPFUNG': 1,
#  'ERHOLEN': 1,
#  'DAVON': 1,
#  'CORONA-SORGEN': 1,
#  'SPIELEN': 1,
#  'WUNSCHZETTELN': 1,
#  'ROLLE': 1,
#  'UNTER': 1,
#  'WEIHNACHTS-POSTSTELLEN': 1,
#  'ENGELSKIRCHEN': 1,
#  'HIMMELSTADT': 1,
#  'KIND': 1,
#  'WÜNSCHEN': 1,
#  'GROSSELTERN': 1,
#  'WIEDERSEHEN': 1,
#  'FREUND': 1,
#  'VERMISSEN': 1,
#  'GRIFF': 1,
#  'SCHLAGEN': 1,
#  'KOMPLETT': 1,
#  'TENDENZIELL': 1,
#  'SOGAR': 1,
#  '@ARMINLASCHET': 1,
#  'CORONA-STERBEFÄLLE': 1,
#  '@RKI_DE': 4,
#  'TOTE': 2,
#  'TODESFÄLLEN': 1,
#  'IMPF-UNWILLIGE': 1,
#  'KULTURVERANSTALTUNGEN': 1,
#  'TEILNEHMEN': 1,
#  'DIESE': 1,
#  'GRAFIK': 2,
#  'VERDEUTLICHEN': 1,
#  'WIRKUNG': 1,
#  'RENTNERIN': 1,
#  'BERUFEN': 1,
#  'GÖTTLICH': 1,
#  ...}

# %%
def write_json(data, file):
    with open(file, mode='w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)
        f.close()

# %%
days = pd.date_range(start=min(dic_frame['date']),end=max(dic_frame['date'])).tolist()

result = []

for day in days:
    word_dic = get_top_k(get_dic_around(date=day, dic_frame=dic_frame, day_range=5), 25)
    
    day_dic = {'day': str(day), 'words': list(word_dic.keys()), 'weights': list(word_dic.values())}
    
    result.append(day_dic)

write_json(result, r'../../corona_data/visual_data.json')
